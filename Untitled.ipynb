# %%
import cv2
import dlib
import numpy as np
from imutils import face_utils
import glob
import os
face_landmark_path = './shape_predictor_68_face_landmarks.dat'

K = [6.5308391993466671e+002, 0.0, 3.1950000000000000e+002,
     0.0, 6.5308391993466671e+002, 2.3950000000000000e+002,
     0.0, 0.0, 1.0]
D = [7.0834633684407095e-002, 6.9140193737175351e-002, 0.0, 0.0, -1.3073460323689292e+000]

cam_matrix = np.array(K).reshape(3, 3).astype(np.float32)
dist_coeffs = np.array(D).reshape(5, 1).astype(np.float32)

object_pts = np.float32([[6.825897, 6.760612, 4.402142],
                         [1.330353, 7.122144, 6.903745],
                         [-1.330353, 7.122144, 6.903745],
                         [-6.825897, 6.760612, 4.402142],
                         [5.311432, 5.485328, 3.987654],
                         [1.789930, 5.393625, 4.413414],
                         [-1.789930, 5.393625, 4.413414],
                         [-5.311432, 5.485328, 3.987654],
                         [2.005628, 1.409845, 6.165652],
                         [-2.005628, 1.409845, 6.165652],
                         [2.774015, -2.080775, 5.048531],
                         [-2.774015, -2.080775, 5.048531],
                         [0.000000, -3.116408, 6.097667],
                         [0.000000, -7.415691, 4.070434]])

reprojectsrc = np.float32([[10.0, 10.0, 10.0],
                           [10.0, 10.0, -10.0],
                           [10.0, -10.0, -10.0],
                           [10.0, -10.0, 10.0],
                           [-10.0, 10.0, 10.0],
                           [-10.0, 10.0, -10.0],
                           [-10.0, -10.0, -10.0],
                           [-10.0, -10.0, 10.0]])

line_pairs = [[0, 1], [1, 2], [2, 3], [3, 0],
              [4, 5], [5, 6], [6, 7], [7, 4],
              [0, 4], [1, 5], [2, 6], [3, 7]]


def get_head_pose(shape):
    image_pts = np.float32([shape[17], shape[21], shape[22], shape[26], shape[36],
                            shape[39], shape[42], shape[45], shape[31], shape[35],
                            shape[48], shape[54], shape[57], shape[8]])

    _, rotation_vec, translation_vec = cv2.solvePnP(object_pts, image_pts, cam_matrix, dist_coeffs)

    reprojectdst, _ = cv2.projectPoints(reprojectsrc, rotation_vec, translation_vec, cam_matrix,
                                        dist_coeffs)

    reprojectdst = tuple(map(tuple, reprojectdst.reshape(8, 2)))

    # calc euler angle
    rotation_mat, _ = cv2.Rodrigues(rotation_vec)
    pose_mat = cv2.hconcat((rotation_mat, translation_vec))
    _, _, _, _, _, _, euler_angle = cv2.decomposeProjectionMatrix(pose_mat)

    return reprojectdst, euler_angle

def main():
    # return
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor(face_landmark_path)
    files = os.listdir(r'./front/')
    files =glob.glob("C:\\Users\\IMCim\\Desktop\\OC最終確認\\納品物\\front")
    for fname in files:
        frame = cv2.imread(fname, cv2.IMREAD_COLOR)
        cv2.imshow('image',frame)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
        print("aa")
        face_rects = detector(frame, 0)

        shape = predictor(frame, face_rects[0])
        shape = face_utils.shape_to_np(shape)
        reprojectdst, euler_angle = get_head_pose(shape)                       
        global fx,fy,fz
        fx=euler_angle[0, 0]
        fy=euler_angle[1, 0]
        fz=euler_angle[2, 0]
        if fy>=17:
            print("右")
        elif fy<=-17:
            print("左")
        else:
            print("正面")
        print(fy)
if __name__ == '__main__':
    main()

# %%
import os
 
path = './front'
 
list1 = os.listdir(path)
print(list1)
# Out:
# ['bobifront2.jpg', 'bobifront3.jpg', 'bobifront4.jpg', 'bobifront5.jpg', 'bobifront6.jpg', 'bobifront7.jpg', 'hondakeisukefront1.jpg', 'hondakeisukefront2.jpg', 'hondakeisukefront3.jpg', 'hondakeisukefront4.jpg', 'hondakeisukefront5.jpg', 'hondakeisukefront6.jpg', 'hondakeisukefront7.jpg', 'hondakeisukefront8.jpg', 'hondatubasafront1.jpg', 'hondatubasafront2.jpg', 'hondatubasafront3.jpg', 'hondatubasafront4.jpg', 'hondatubasafront5.jpg', 'hondatubasafront6.jpg', 'hondatubasafront7.jpg', 'hondatubasafront8.jpg', 'motokifront1.jpg', 'ndahofront1.jpg', 'sirukufront1.jpg', 'sirukufront2.jpg', 'sirukufront3.jpg', 'sirukufront4.jpg']

# %%
import cv2
import dlib
import numpy as np
from imutils import face_utils
import glob
import os
face_landmark_path = '../shape_predictor_68_face_landmarks.dat'

K = [6.5308391993466671e+002, 0.0, 3.1950000000000000e+002,
     0.0, 6.5308391993466671e+002, 2.3950000000000000e+002,
     0.0, 0.0, 1.0]
D = [7.0834633684407095e-002, 6.9140193737175351e-002, 0.0, 0.0, -1.3073460323689292e+000]

cam_matrix = np.array(K).reshape(3, 3).astype(np.float32)
dist_coeffs = np.array(D).reshape(5, 1).astype(np.float32)

object_pts = np.float32([[6.825897, 6.760612, 4.402142],
                         [1.330353, 7.122144, 6.903745],
                         [-1.330353, 7.122144, 6.903745],
                         [-6.825897, 6.760612, 4.402142],
                         [5.311432, 5.485328, 3.987654],
                         [1.789930, 5.393625, 4.413414],
                         [-1.789930, 5.393625, 4.413414],
                         [-5.311432, 5.485328, 3.987654],
                         [2.005628, 1.409845, 6.165652],
                         [-2.005628, 1.409845, 6.165652],
                         [2.774015, -2.080775, 5.048531],
                         [-2.774015, -2.080775, 5.048531],
                         [0.000000, -3.116408, 6.097667],
                         [0.000000, -7.415691, 4.070434]])

reprojectsrc = np.float32([[10.0, 10.0, 10.0],
                           [10.0, 10.0, -10.0],
                           [10.0, -10.0, -10.0],
                           [10.0, -10.0, 10.0],
                           [-10.0, 10.0, 10.0],
                           [-10.0, 10.0, -10.0],
                           [-10.0, -10.0, -10.0],
                           [-10.0, -10.0, 10.0]])

line_pairs = [[0, 1], [1, 2], [2, 3], [3, 0],
              [4, 5], [5, 6], [6, 7], [7, 4],
              [0, 4], [1, 5], [2, 6], [3, 7]]


def get_head_pose(shape):
    image_pts = np.float32([shape[17], shape[21], shape[22], shape[26], shape[36],
                            shape[39], shape[42], shape[45], shape[31], shape[35],
                            shape[48], shape[54], shape[57], shape[8]])

    _, rotation_vec, translation_vec = cv2.solvePnP(object_pts, image_pts, cam_matrix, dist_coeffs)

    reprojectdst, _ = cv2.projectPoints(reprojectsrc, rotation_vec, translation_vec, cam_matrix,
                                        dist_coeffs)

    reprojectdst = tuple(map(tuple, reprojectdst.reshape(8, 2)))

    # calc euler angle
    rotation_mat, _ = cv2.Rodrigues(rotation_vec)
    pose_mat = cv2.hconcat((rotation_mat, translation_vec))
    _, _, _, _, _, _, euler_angle = cv2.decomposeProjectionMatrix(pose_mat)

    return reprojectdst, euler_angle

def main():
    # return
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor(face_landmark_path)
#    files =glob.glob("C:\\Users\\IMCim\\Desktop\\OC最終確認\\納品物\\front")
    for a in glob.glob('*.jpg'):
        frame = cv2.imread(a)
        cv2.imshow('image',frame)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
        face_rects = detector(frame, 0)

        shape = predictor(frame, face_rects[0])
        shape = face_utils.shape_to_np(shape)
        reprojectdst, euler_angle = get_head_pose(shape)                       
        global fx,fy,fz
        fx=euler_angle[0, 0]
        fy=euler_angle[1, 0]
        fz=euler_angle[2, 0]
        if fy>=17:
            print("右")
        elif fy<=-17:
            print("左")
        else:
            print("正面")
        print(fy)
if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-ae6e7d843d4d> in <module>
#      90         print(fy)
#      91 if __name__ == '__main__':
# ---> 92     main()
#
# <ipython-input-10-ae6e7d843d4d> in main()
#      75         face_rects = detector(frame, 0)
#      76
# ---> 77         shape = predictor(frame, face_rects[0])
#      78         shape = face_utils.shape_to_np(shape)
#      79         reprojectdst, euler_angle = get_head_pose(shape)
#
# IndexError:

# %%
import cv2
import dlib
import numpy as np
from imutils import face_utils

face_landmark_path = './shape_predictor_68_face_landmarks.dat'

K = [6.5308391993466671e+002, 0.0, 3.1950000000000000e+002,
     0.0, 6.5308391993466671e+002, 2.3950000000000000e+002,
     0.0, 0.0, 1.0]
D = [7.0834633684407095e-002, 6.9140193737175351e-002, 0.0, 0.0, -1.3073460323689292e+000]

cam_matrix = np.array(K).reshape(3, 3).astype(np.float32)
dist_coeffs = np.array(D).reshape(5, 1).astype(np.float32)

object_pts = np.float32([[6.825897, 6.760612, 4.402142],
                         [1.330353, 7.122144, 6.903745],
                         [-1.330353, 7.122144, 6.903745],
                         [-6.825897, 6.760612, 4.402142],
                         [5.311432, 5.485328, 3.987654],
                         [1.789930, 5.393625, 4.413414],
                         [-1.789930, 5.393625, 4.413414],
                         [-5.311432, 5.485328, 3.987654],
                         [2.005628, 1.409845, 6.165652],
                         [-2.005628, 1.409845, 6.165652],
                         [2.774015, -2.080775, 5.048531],
                         [-2.774015, -2.080775, 5.048531],
                         [0.000000, -3.116408, 6.097667],
                         [0.000000, -7.415691, 4.070434]])

reprojectsrc = np.float32([[10.0, 10.0, 10.0],
                           [10.0, 10.0, -10.0],
                           [10.0, -10.0, -10.0],
                           [10.0, -10.0, 10.0],
                           [-10.0, 10.0, 10.0],
                           [-10.0, 10.0, -10.0],
                           [-10.0, -10.0, -10.0],
                           [-10.0, -10.0, 10.0]])

line_pairs = [[0, 1], [1, 2], [2, 3], [3, 0],
              [4, 5], [5, 6], [6, 7], [7, 4],
              [0, 4], [1, 5], [2, 6], [3, 7]]


def get_head_pose(shape):
    image_pts = np.float32([shape[17], shape[21], shape[22], shape[26], shape[36],
                            shape[39], shape[42], shape[45], shape[31], shape[35],
                            shape[48], shape[54], shape[57], shape[8]])

    _, rotation_vec, translation_vec = cv2.solvePnP(object_pts, image_pts, cam_matrix, dist_coeffs)

    reprojectdst, _ = cv2.projectPoints(reprojectsrc, rotation_vec, translation_vec, cam_matrix,
                                        dist_coeffs)

    reprojectdst = tuple(map(tuple, reprojectdst.reshape(8, 2)))

    # calc euler angle
    rotation_mat, _ = cv2.Rodrigues(rotation_vec)
    pose_mat = cv2.hconcat((rotation_mat, translation_vec))
    _, _, _, _, _, _, euler_angle = cv2.decomposeProjectionMatrix(pose_mat)

    return reprojectdst, euler_angle


def main():
    # return
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor(face_landmark_path)

    frame = cv2.imread("bobifront2.jpg")
    face_rects = detector(frame, 0)

    shape = predictor(frame, face_rects[0])
    shape = face_utils.shape_to_np(shape)
    reprojectdst, euler_angle = get_head_pose(shape)                       
    global fx,fy,fz
    fx=euler_angle[0, 0]
    fy=euler_angle[1, 0]
    fz=euler_angle[2, 0]
        
    print(fx)
    print(fy)
    print(fz)
if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-82eb32f38646> in <module>
#      83     print(fz)
#      84 if __name__ == '__main__':
# ---> 85     main()
#
# <ipython-input-11-82eb32f38646> in main()
#      69
#      70     frame = cv2.imread("bobifront2.jpg")
# ---> 71     face_rects = detector(frame, 0)
#      72
#      73     shape = predictor(frame, face_rects[0])
#
# TypeError: __call__(): incompatible function arguments. The following argument types are supported:
#     1. (self: dlib.fhog_object_detector, image: array, upsample_num_times: int=0) -> dlib.rectangles
#
# Invoked with: <dlib.fhog_object_detector object at 0x00000277C375C618>, None, 0
